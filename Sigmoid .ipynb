# %%
import numpy as np

# %%
def sigmoid(z):
    val = 1 / (1+np.exp(-z))
    return val

# %%
sigmoid(1.3)
# Out:
# 0.7858349830425586

# %%
sigmoid(-4.03667)
# Out:
# 0.017349837992035204

# %%
sigmoid(8.90)
# Out:
# 0.9998636296729204

# %%
sigmoid(17637)
# Out:
# 1.0

# %%
def softmax(z):
    val = np.exp(z) / np.sum(np.exp(z))
    return val

# %%
softmax([3.4, 7.1, 0.45, 2.67])
# Out:
# array([0.02381999, 0.96345422, 0.00124673, 0.01147907])

# %%
sum([0.02381999, 0.96345422, 0.00124673, 0.01147907])
# Out:
# 1.00000001

# %%
softmax([3.4, 7.1, 0.45, 2.67, 7.3, 6.5, 5.2 ])
# Out:
# array([0.008359  , 0.33809883, 0.00043751, 0.00402828, 0.41295484,
#        0.18555257, 0.05056898])

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(-10, 10, 0.25)
y = x * 4.23 + 36.07
plt.plot(x, y)

# %%
def sigmoid(z):
    val = 1 / (1 + np.exp(-z))
    return val

# %%
plt.plot(x, sigmoid(x))
